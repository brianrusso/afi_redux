# %%
import topycal
import os
import glob
import random

INSTR_PATH = os.path.join(os.getcwd(),"afi_txt")

# %%
from concurrent.futures import ThreadPoolExecutor, wait, as_completed
def do_fn_on_iter(fn, iterator, num_threads=6):
    futures = []
    if isinstance(num_threads, str):
        num_threads = int(num_threads)
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        for elem in iterator:
            futures.append(executor.submit(fn, elem))
    results = []
    for x in as_completed(futures):
        results.append(x.result())
    return results

# %%
def get_file_list(limit=500, shuffle=True):
    files = glob.glob("{}/afi*.txt".format(INSTR_PATH))
    if shuffle:
        random.shuffle(files)
    if limit:
        return files[0:limit]
    else:
        return files
    #data = myfile.read()
    
def read_file(fname):
    with open(fname, errors='replace') as fd:
        return fd.read()

# %%
file_list = get_file_list(limit=None)

# %%
import re
import os

def load_file(fname):       
    with open(fname, 'r') as myfile:
        contents = re.sub(r'[\t\n\r\x0b\x0c]',' ', myfile.read())
        return (os.path.basename(fname),re.sub("\s+",' ', contents))

def load_corpus(file_list):
    return {f[0]:f[1] for f in do_fn_on_iter(load_file, file_list)}

# %%
corpus_dict = load_corpus(file_list)

# %%
import spacy
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# For each document, we sentence segment then create a basket based on the 64bit murmurhash (after whitespace trimming and checking for a minimum sentence threshold).

# %%
import mmh3

from tqdm import tqdm
from collections import defaultdict

MIN_SENT_LEN = 15

def do_market_basket_analysis(doc_dict):
    baskets = defaultdict(set)
    reverselut = {}
    for k,v in tqdm(doc_dict.items()):
        for sent in nlp(v).sents:
            if len(sent) > MIN_SENT_LEN:
                this_hash = mmh3.hash64(sent.text.strip())
                baskets[this_hash].add(k)
                reverselut[sent.text] = this_hash
    return (baskets,reverselut)

# %%
baskets,reverselut = do_market_basket_analysis(corpus_dict)
# Out:
# 100%|██████████| 1141/1141 [18:32<00:00,  1.80it/s]

# %% [markdown]
# Each basket is trimmed based on being a certain minimum size.. logic here is to reduce noise.

# %%
this_hash = reverselut['Establish, monitor, and verify supervisory inspections on elements assigned with equipment and CTK’s are completed.']
#baskets[this_hash]
sent_to_hash = reverselut
hash_to_sent = {v:k for k,v in reverselut.items()}

# %%
def count_docs():
    doc_count = {}
    for k,v in trimmed_baskets.items():
        for doc in v:
            try:
                doc_count[doc] += 1
            except KeyError:
                doc_count[doc] = 1
    return doc_count

# %%
doccount = count_docs()

# %%
doccount
# Out:
# {'afi1-404.txt': 4,
#  'afi10-1701.txt': 4,
#  'afi10-1703v1.txt': 7,
#  'afi10-1703v2.txt': 5,
#  'afi10-1703v3.txt': 4,
#  'afi10-201.txt': 4,
#  'afi10-202.txt': 7,
#  'afi10-203.txt': 4,
#  'afi10-204.txt': 3,
#  'afi10-206.txt': 2,
#  'afi10-207.txt': 4,
#  'afi10-208.txt': 1,
#  'afi10-209.txt': 2,
#  'afi10-210.txt': 2,
#  'afi10-213.txt': 3,
#  'afi10-216.txt': 4,
#  'afi10-2402.txt': 1,
#  'afi10-244.txt': 1,
#  'afi10-250.txt': 6,
#  'afi10-2501.txt': 3,
#  'afi10-251.txt': 3,
#  'afi10-2519.txt': 6,
#  'afi10-2607.txt': 2,
#  'afi10-2909.txt': 3,
#  'afi10-3002.txt': 4,
#  'afi10-301.txt': 3,
#  'afi10-3502v1.txt': 6,
#  'afi10-3502v2.txt': 14,
#  'afi10-401.txt': 2,
#  'afi10-402.txt': 3,
#  'afi10-403.txt': 6,
#  'afi10-410.txt': 1,
#  'afi10-414.txt': 1,
#  'afi10-420.txt': 3,
#  'afi10-4201v1.txt': 3,
#  'afi10-4201v3.txt': 5,
#  'afi10-421.txt': 3,
#  'afi10-501.txt': 2,
#  'afi10-503.txt': 1,
#  'afi10-601.txt': 1,
#  'afi10-701.txt': 5,
#  'afi10-703.txt': 1,
#  'afi10-706.txt': 1,
#  'afi10-707.txt': 3,
#  'afi10-712.txt': 5,
#  'afi11-101.txt': 2,
#  'afi11-201v1.txt': 3,
#  'afi11-202v2.txt': 1,
#  'afi11-202v3.txt': 4,
#  'afi11-207.txt': 4,
#  'afi11-215.txt': 3,
#  'afi11-218.txt': 3,
#  'afi11-221.txt': 5,
#  'afi11-235.txt': 1,
#  'afi11-246v1.txt': 4,
#  'afi11-246v7.txt': 2,
#  'afi11-253.txt': 1,
#  'afi11-255v1.txt': 1,
#  'afi11-255v2.txt': 2,
#  'afi11-255v3.txt': 16,
#  'afi11-260.txt': 1,
#  'afi11-289.txt': 3,
#  'afi11-290.txt': 2,
#  'afi11-2a-10cv2.txt': 24,
#  'afi11-2a-10cv3.txt': 24,
#  'afi11-2a-oa-10v1.txt': 1,
#  'afi11-2ac-130v1.txt': 28,
#  'afi11-2ac-130v2.txt': 61,
#  'afi11-2ac-130v3.txt': 104,
#  'afi11-2ac-130wv1.txt': 24,
#  'afi11-2ac-130wv2.txt': 55,
#  'afi11-2ac-130wv3.txt': 143,
#  'afi11-2ac-130wv3adda.txt': 2,
#  'afi11-2aev1.txt': 20,
#  'afi11-2aev2.txt': 11,
#  'afi11-2aev3.txt': 264,
#  'afi11-2aev3addenda-a.txt': 3,
#  'afi11-2b-1v1.txt': 14,
#  'afi11-2b-1v3.txt': 5,
#  'afi11-2b-2v1.txt': 14,
#  'afi11-2b-2v2.txt': 15,
#  'afi11-2b-2v3.txt': 5,
#  'afi11-2b-52v1.txt': 12,
#  'afi11-2b-52v2.txt': 11,
#  'afi11-2b-52v3.txt': 3,
#  'afi11-2c-12v1.txt': 32,
#  'afi11-2c-12v2.txt': 32,
#  'afi11-2c-12v3.txt': 313,
#  'afi11-2c-130jv1.txt': 52,
#  'afi11-2c-130jv2.txt': 17,
#  'afi11-2c-130jv3.txt': 493,
#  'afi11-2c-130jv3adda.txt': 2,
#  'afi11-2c-130jv3addb.txt': 3,
#  'afi11-2c-130v1.txt': 52,
#  'afi11-2c-130v2.txt': 18,
#  'afi11-2c-130v3.txt': 597,
#  'afi11-2c-130v3adda.txt': 5,
#  'afi11-2c-130v3addb.txt': 4,
#  'afi11-2c-130v3addd.txt': 6,
#  'afi11-2c-145av1.txt': 21,
#  'afi11-2c-145av2.txt': 68,
#  'afi11-2c-145av3.txt': 88,
#  'afi11-2c-146av1.txt': 22,
#  'afi11-2c-146av3.txt': 83,
#  'afi11-2c-17v1.txt': 27,
#  'afi11-2c-17v2.txt': 3,
#  'afi11-2c-17v3.txt': 654,
#  'afi11-2c-17v3add-a.txt': 7,
#  'afi11-2c-17v3add-c.txt': 2,
#  'afi11-2c-21v1.txt': 49,
#  'afi11-2c-21v2.txt': 28,
#  'afi11-2c-21v3.txt': 641,
#  'afi11-2c-32bv1.txt': 16,
#  'afi11-2c-32bv3.txt': 59,
#  'afi11-2c-38v1.txt': 6,
#  'afi11-2c-38v2.txt': 25,
#  'afi11-2c-38v3.txt': 321,
#  'afi11-2c-3bv2.txt': 32,
#  'afi11-2c-5v1.txt': 40,
#  'afi11-2c-5v2.txt': 25,
#  'afi11-2c-5v3.txt': 633,
#  'afi11-2c-5v3_addenda-a.txt': 3,
#  'afi11-2cap-usafv2.txt': 3,
#  'afi11-2cap-usafv3.txt': 1,
#  'afi11-2cv-22v1.txt': 10,
#  'afi11-2cv-22v2.txt': 53,
#  'afi11-2cv-22v3.txt': 39,
#  'afi11-2e-11v1.txt': 9,
#  'afi11-2e-11v2.txt': 20,
#  'afi11-2e-11v3.txt': 32,
#  'afi11-2e-3v1.txt': 3,
#  'afi11-2e-3v2.txt': 6,
#  'afi11-2e-3v3.txt': 6,
#  'afi11-2e-4bv2.txt': 5,
#  'afi11-2e-4v1.txt': 4,
#  'afi11-2e-4v3.txt': 26,
#  'afi11-2e-8v1.txt': 10,
#  'afi11-2e-8v2.txt': 5,
#  'afi11-2e-8v3.txt': 22,
#  'afi11-2e-9v1.txt': 8,
#  'afi11-2e-9v2.txt': 20,
#  'afi11-2e-9v3.txt': 82,
#  'afi11-2eav1.txt': 49,
#  'afi11-2ec-130hv1.txt': 8,
#  'afi11-2ec-130hv2.txt': 41,
#  'afi11-2ec-130hv3.txt': 233,
#  'afi11-2ec-130jv1.txt': 25,
#  'afi11-2ec-130jv2.txt': 74,
#  'afi11-2ec-130jv3.txt': 183,
#  'afi11-2ec-137v3.txt': 3,
#  'afi11-2ec-mc-130jv3_adda-a.txt': 4,
#  'afi11-2f-15ev1.txt': 11,
#  'afi11-2f-15ev2.txt': 32,
#  'afi11-2f-15ev3.txt': 22,
#  'afi11-2f-15v1.txt': 15,
#  'afi11-2f-15v2.txt': 32,
#  'afi11-2f-15v3.txt': 27,
#  'afi11-2f-16v1.txt': 12,
#  'afi11-2f-16v2.txt': 34,
#  'afi11-2f-16v3.txt': 22,
#  'afi11-2f-22av3.txt': 21,
#  'afi11-2f-35av1.txt': 11,
#  'afi11-2f-35av2.txt': 35,
#  'afi11-2f-35av3.txt': 23,
#  'afi11-2ftv1.txt': 25,
#  'afi11-2ftv2.txt': 41,
#  'afi11-2ftv3.txt': 52,
#  'afi11-2hc-130jv1.txt': 32,
#  'afi11-2hc-130jv2.txt': 64,
#  'afi11-2hc-130jv3.txt': 195,
#  'afi11-2hc-130jv3_addenda-a.txt': 6,
#  'afi11-2hc-130jv3cl-1.txt': 4,
#  'afi11-2hc-130jv3cl-2.txt': 4,
#  'afi11-2hc-130v1.txt': 35,
#  'afi11-2hc-130v2.txt': 66,
#  'afi11-2hc-130v3.txt': 107,
#  'afi11-2hh-60v1.txt': 15,
#  'afi11-2hh-60v2.txt': 5,
#  'afi11-2hh-60v3.txt': 2,
#  'afi11-2kc-10v1.txt': 42,
#  'afi11-2kc-10v2.txt': 32,
#  'afi11-2kc-10v3.txt': 644,
#  'afi11-2kc-10v3_addenda-a.txt': 6,
#  'afi11-2kc-135v1.txt': 42,
#  'afi11-2kc-135v2.txt': 23,
#  'afi11-2kc-135v3.txt': 595,
#  'afi11-2kc-135v3_addenda-a.txt': 4,
#  'afi11-2mc-12wv1.txt': 11,
#  'afi11-2mc-12wv2.txt': 20,
#  'afi11-2mc-12wv3.txt': 106,
#  'afi11-2mc-130jv1.txt': 21,
#  'afi11-2mc-130jv2.txt': 73,
#  'afi11-2mc-130jv3.txt': 174,
#  'afi11-2mc-130v1.txt': 22,
#  'afi11-2mc-130v2.txt': 39,
#  'afi11-2mc-130v3.txt': 107,
#  'afi11-2mc-130v3addb.txt': 3,
#  'afi11-2mc-130v3cl-1.txt': 1,
#  'afi11-2mc-130v3cl-4.txt': 1,
#  'afi11-2mc-130v3cl-5.txt': 1,
#  'afi11-2mq-1&9v1.txt': 10,
#  'afi11-2mq-1&9v3.txt': 4,
#  'afi11-2mq-1v2.txt': 19,
#  'afi11-2mq-9v2.txt': 2,
#  'afi11-2qf-16v1.txt': 8,
#  'afi11-2qf-16v2.txt': 32,
#  'afi11-2qf-16v3.txt': 8,
#  'afi11-2rc-135v1.txt': 9,
#  'afi11-2rc-135v2.txt': 6,
#  'afi11-2rc-135v3.txt': 12,
#  'afi11-2rc-26bv1.txt': 28,
#  'afi11-2rc-26bv2.txt': 3,
#  'afi11-2rc-26bv3.txt': 1,
#  'afi11-2rq-4v1.txt': 1,
#  'afi11-2rq-4v2.txt': 15,
#  'afi11-2rq-4v3.txt': 3,
#  'afi11-2sailplanev1.txt': 3,
#  'afi11-2sailplanev2.txt': 2,
#  'afi11-2sailplanev3.txt': 5,
#  'afi11-2t-1v1.txt': 3,
#  'afi11-2t-1v2.txt': 5,
#  'afi11-2t-1v3.txt': 3,
#  'afi11-2t-38v1.txt': 6,
#  'afi11-2t-38v2.txt': 5,
#  'afi11-2t-38v3.txt': 2,
#  'afi11-2t-41-51-53v1.txt': 3,
#  'afi11-2t-41-51-53v2.txt': 5,
#  'afi11-2t-41-51-53v3.txt': 3,
#  'afi11-2t-6v1.txt': 7,
#  'afi11-2t-6v2.txt': 4,
#  'afi11-2t-6v3.txt': 5,
#  'afi11-2th-1hv1.txt': 1,
#  'afi11-2th-1hv2.txt': 1,
#  'afi11-2th-1hv3.txt': 2,
#  'afi11-2u-28av1.txt': 22,
#  'afi11-2u-28v2.txt': 62,
#  'afi11-2u-28v3.txt': 83,
#  'afi11-2u-2v1.txt': 4,
#  'afi11-2u-2v2.txt': 8,
#  'afi11-2u-2v3.txt': 8,
#  'afi11-2uh-1nv1.txt': 8,
#  'afi11-2uh-1nv2.txt': 34,
#  'afi11-2uh-1nv3.txt': 5,
#  'afi11-2uh-1nv3cl-1.txt': 4,
#  'afi11-2uh-th-1hv3cl-1.txt': 1,
#  'afi11-2uv-18v1.txt': 3,
#  'afi11-2uv-18v2.txt': 2,
#  'afi11-2uv-18v3.txt': 4,
#  'afi11-2vipv2.txt': 28,
#  'afi11-2vipv3.txt': 312,
#  'afi11-301v1.txt': 1,
#  'afi11-301v2.txt': 1,
#  'afi11-301v3.txt': 4,
#  'afi11-301v5.txt': 6,
#  'afi11-401.txt': 1,
#  'afi11-402.txt': 3,
#  'afi11-403.txt': 2,
#  'afi11-404.txt': 5,
#  'afi11-405.txt': 3,
#  'afi11-409.txt': 6,
#  'afi11-412.txt': 1,
#  'afi11-418.txt': 3,
#  'afi11-421.txt': 3,
#  'afi11-502v1.txt': 2,
#  'afi11-502v2.txt': 2,
#  'afi11-5ftv1.txt': 22,
#  'afi11-5ftv2.txt': 16,
#  'afi11-5ftv3.txt': 20,
#  'afi13-103.txt': 2,
#  'afi13-112v1.txt': 4,
#  'afi13-112v2.txt': 8,
#  'afi13-113v1_afgm2016-01_(2).txt': 6,
#  'afi13-114v1.txt': 6,
#  'afi13-114v3.txt': 2,
#  'afi13-1_bccv2.txt': 3,
#  'afi13-1bccv1.txt': 3,
#  'afi13-1bccv3.txt': 7,
#  'afi13-1crcan_tyq-23av1.txt': 6,
#  'afi13-1crcv1.txt': 5,
#  'afi13-1crcv2.txt': 6,
#  'afi13-1crcv3.txt': 5,
#  'afi13-1stan-evalv2.txt': 7,
#  'afi13-201.txt': 1,
#  'afi13-202.txt': 5,
#  'afi13-204v1.txt': 5,
#  'afi13-204v2.txt': 5,
#  'afi13-204v3.txt': 5,
#  'afi13-204v4.txt': 5,
#  'afi13-208.txt': 2,
#  'afi13-212v1.txt': 4,
#  'afi13-213.txt': 5,
#  'afi13-219v1.txt': 1,
#  'afi13-219v2.txt': 1,
#  'afi13-415.txt': 3,
#  'afi13-503.txt': 3,
#  'afi13-504.txt': 3,
#  'afi13-520.txt': 3,
#  'afi13-526v1.txt': 6,
#  'afi13-526v2.txt': 5,
#  'afi13-526v3.txt': 5,
#  'afi13-526v4.txt': 5,
#  'afi13-527.txt': 7,
#  'afi13-530.txt': 4,
#  'afi13-550.txt': 3,
#  'afi13-601.txt': 6,
#  'afi14-101.txt': 3,
#  'afi14-104.txt': 6,
#  'afi14-111.txt': 2,
#  'afi14-117.txt': 5,
#  'afi14-120.txt': 1,
#  'afi14-125.txt': 3,
#  'afi14-128.txt': 2,
#  'afi14-130.txt': 6,
#  'afi14-132.txt': 2,
#  'afi14-133.txt': 2,
#  'afi14-134.txt': 3,
#  'afi14-135.txt': 4,
#  'afi14-202v1.txt': 8,
#  'afi14-202v2.txt': 8,
#  'afi14-202v3.txt': 11,
#  'afi14-2a-10v1.txt': 157,
#  'afi14-2a-10v2.txt': 102,
#  'afi14-2a-10v3.txt': 85,
#  'afi14-2afsofv1.txt': 8,
#  'afi14-2afsofv2.txt': 25,
#  'afi14-2afsofv3.txt': 18,
#  'afi14-2asog_v1.txt': 58,
#  'afi14-2asogv3.txt': 10,
#  'afi14-2b-1v1.txt': 146,
#  'afi14-2b-1v2.txt': 98,
#  'afi14-2b-1v3.txt': 85,
#  'afi14-2b-2v1.txt': 36,
#  'afi14-2b-2v2.txt': 42,
#  'afi14-2b-2v3.txt': 21,
#  'afi14-2b-52v1.txt': 37,
#  'afi14-2b-52v2.txt': 34,
#  'afi14-2b-52v3.txt': 19,
#  'afi14-2c-130.txt': 22,
#  'afi14-2cr.txt': 17,
#  'afi14-2crcv1.txt': 51,
#  'afi14-2crcv2.txt': 36,
#  'afi14-2crcv3.txt': 22,
#  'afi14-2e-3v1.txt': 111,
#  'afi14-2e-3v2.txt': 65,
#  'afi14-2e-3v3.txt': 51,
#  'afi14-2e-8v1.txt': 58,
#  'afi14-2e-8v2.txt': 49,
#  'afi14-2e-8v3.txt': 40,
#  'afi14-2ec-130hv1.txt': 76,
#  'afi14-2ec-130hv3.txt': 39,
#  'afi14-2f-15cv1.txt': 139,
#  'afi14-2f-15cv2.txt': 99,
#  'afi14-2f-15cv3.txt': 85,
#  'afi14-2f-15ev1.txt': 144,
#  'afi14-2f-15ev2.txt': 96,
#  'afi14-2f-15ev3.txt': 79,
#  'afi14-2f-16v1.txt': 40,
#  'afi14-2f-16v2.txt': 45,
#  'afi14-2f-16v3.txt': 28,
#  'afi14-2f-22v1.txt': 159,
#  'afi14-2f-22v2.txt': 103,
#  'afi14-2f-22v3.txt': 85,
#  'afi14-2mc-12v1.txt': 45,
#  'afi14-2mc-12v3.txt': 37,
#  'afi14-2mq-1&9v1.txt': 42,
#  'afi14-2mq-1&9v2.txt': 21,
#  'afi14-2mq-1&9v3.txt': 28,
#  'afi14-2prv1.txt': 52,
#  'afi14-2prv2.txt': 25,
#  'afi14-2prv3.txt': 39,
#  'afi14-2rc-135v1.txt': 63,
#  'afi14-2rc-135v2.txt': 25,
#  'afi14-2rc-135v3.txt': 46,
#  'afi14-2rq-4v1.txt': 44,
#  'afi14-2rq-4v2.txt': 26,
#  'afi14-2rq-4v3.txt': 34,
#  'afi14-2space.txt': 11,
#  'afi14-2u-2v1.txt': 109,
#  'afi14-2u-2v2.txt': 59,
#  'afi14-2u-2v3.txt': 56,
#  'afi14-2vip.txt': 22,
#  'afi15-114.txt': 1,
#  'afi15-127.txt': 1,
#  'afi15-128.txt': 1,
#  'afi15-135v1.txt': 2,
#  'afi15-135v2.txt': 2,
#  'afi15-135v3.txt': 3,
#  'afi15-182.txt': 3,
#  'afi16-1001.txt': 5,
#  'afi16-1005.txt': 5,
#  'afi16-102.txt': 1,
#  'afi16-108.txt': 2,
#  'afi16-109.txt': 2,
#  'afi16-116.txt': 1,
#  'afi16-1301.txt': 6,
#  'afi16-1404.txt': 4,
#  'afi16-1406.txt': 1,
#  'afi16-201.txt': 4,
#  'afi16-401.txt': 2,
#  'afi16-402.txt': 2,
#  'afi16-601.txt': 3,
#  'afi16-603.txt': 3,
#  'afi16-604.txt': 2,
#  'afi16-605.txt': 1,
#  'afi16-606.txt': 1,
#  'afi16-608.txt': 4,
#  'afi16-609.txt': 3,
#  'afi16-701.txt': 2,
#  'afi17-101.txt': 2,
#  'afi17-102.txt': 1,
#  'afi17-140.txt': 2,
#  'afi17-203.txt': 2,
#  'afi17-204.txt': 1,
#  'afi17-212.txt': 4,
#  'afi17-213.txt': 5,
#  'afi17-220.txt': 3,
#  'afi17-2acdv2.txt': 8,
#  'afi17-2acdv3.txt': 8,
#  'afi17-2afincv1.txt': 14,
#  'afi17-2afincv2.txt': 8,
#  'afi17-2afincv3.txt': 7,
#  'afi17-2cdav1.txt': 13,
#  'afi17-2cdav2.txt': 8,
#  'afi17-2cdav3.txt': 8,
#  'afi17-2cscsv1.txt': 14,
#  'afi17-2cscsv2.txt': 9,
#  'afi17-2cscsv3.txt': 9,
#  'afi17-2nasv1.txt': 9,
#  'afi17-2nasv2.txt': 7,
#  'afi17-2nasv3.txt': 5,
#  'afi20-110.txt': 3,
#  'afi20-112.txt': 4,
#  'afi20-114.txt': 1,
#  'afi20-117.txt': 3,
#  'afi20-118.txt': 4,
#  'afi20-119.txt': 3,
#  'afi21-101.txt': 1,
#  'afi21-110.txt': 3,
#  'afi21-111.txt': 4,
#  'afi21-113.txt': 6,
#  'afi21-123.txt': 2,
#  'afi21-124.txt': 6,
#  'afi21-136.txt': 4,
#  'afi21-150.txt': 5,
#  'afi21-200.txt': 1,
#  'afi21-201.txt': 2,
#  'afi21-202v1.txt': 4,
#  'afi21-202v2.txt': 2,
#  'afi21-203.txt': 2,
#  'afi21-204.txt': 2,
#  'afi21-210.txt': 4,
#  'afi21-214.txt': 4,
#  'afi23-101.txt': 5,
#  'afi23-106.txt': 4,
#  'afi23-111.txt': 1,
#  'afi23-119.txt': 1,
#  'afi23-201.txt': 3,
#  'afi23-204.txt': 1,
#  'afi23-502.txt': 3,
#  'afi24-101.txt': 3,
#  'afi24-114.txt': 3,
#  'afi24-203.txt': 4,
#  'afi24-301.txt': 6,
#  'afi24-501.txt': 1,
#  'afi25-101.txt': 1,
#  'afi25-201.txt': 1,
#  'afi25-202.txt': 4,
#  'afi25-301.txt': 1,
#  'afi31-105.txt': 3,
#  'afi31-115.txt': 1,
#  'afi31-118.txt': 1,
#  'afi31-122.txt': 4,
#  'afi31-126.txt': 1,
#  'afi31-208.txt': 4,
#  'afi31-218.txt': 1,
#  'afi32-1001.txt': 6,
#  'afi32-1002.txt': 5,
#  'afi32-10141.txt': 4,
#  'afi32-10142.txt': 3,
#  'afi32-1021.txt': 2,
#  'afi32-1022.txt': 4,
#  'afi32-1023.txt': 4,
#  'afi32-1024.txt': 2,
#  'afi32-1032.txt': 4,
#  'afi32-1041.txt': 4,
#  'afi32-1042.txt': 5,
#  'afi32-1043.txt': 5,
#  'afi32-1044.txt': 6,
#  'afi32-1051.txt': 8,
#  'afi32-1052.txt': 2,
#  'afi32-1053.txt': 6,
#  'afi32-1054.txt': 6,
#  'afi32-1061.txt': 3,
#  'afi32-1062.txt': 4,
#  'afi32-1064.txt': 6,
#  'afi32-1065.txt': 3,
#  'afi32-1067.txt': 1,
#  'afi32-1068.txt': 1,
#  'afi32-1074.txt': 6,
#  'afi32-2001.txt': 1,
#  'afi32-2006.txt': 2,
#  'afi32-3001.txt': 3,
#  'afi32-6001.txt': 2,
#  'afi32-6002.txt': 4,
#  'afi32-6003.txt': 3,
#  'afi32-6004.txt': 6,
#  'afi32-6005.txt': 6,
#  'afi32-6007.txt': 1,
#  'afi32-7001.txt': 4,
#  'afi32-7020.txt': 5,
#  'afi32-7040.txt': 4,
#  'afi32-7042.txt': 3,
#  'afi32-7044.txt': 1,
#  'afi32-7047.txt': 4,
#  'afi32-7062.txt': 1,
#  'afi32-7063.txt': 4,
#  'afi32-7064.txt': 5,
#  'afi32-7065.txt': 5,
#  'afi32-7066.txt': 4,
#  'afi32-7070.txt': 4,
#  'afi32-7086.txt': 4,
#  'afi32-7091.txt': 5,
#  'afi32-9001.txt': 4,
#  'afi32-9002.txt': 5,
#  'afi32-9005.txt': 6,
#  'afi33-115.txt': 3,
#  'afi33-150.txt': 3,
#  'afi33-200.txt': 4,
#  'afi33-301.txt': 6,
#  'afi33-320.txt': 3,
#  'afi33-322.txt': 5,
#  'afi33-324.txt': 3,
#  'afi33-360.txt': 7,
#  'afi33-364.txt': 5,
#  'afi33-393.txt': 2,
#  'afi33-396.txt': 5,
#  'afi33-397.txt': 3,
#  'afi34-101.txt': 1,
#  'afi34-103.txt': 1,
#  'afi34-104.txt': 2,
#  'afi34-1101.txt': 3,
#  'afi34-111.txt': 5,
#  'afi34-117.txt': 3,
#  'afi34-118.txt': 1,
#  'afi34-1201.txt': 3,
#  'afi34-135.txt': 2,
#  'afi34-144.txt': 4,
#  'afi34-148.txt': 3,
#  'afi34-150.txt': 2,
#  'afi34-202.txt': 1,
#  'afi34-208.txt': 1,
#  'afi34-225.txt': 1,
#  'afi34-239.txt': 2,
#  'afi34-266.txt': 2,
#  'afi34-271.txt': 1,
#  'afi34-275.txt': 1,
#  'afi34-301.txt': 1,
#  'afi34-305.txt': 2,
#  'afi34-306.txt': 1,
#  'afi34-307.txt': 1,
#  'afi34-308.txt': 2,
#  'afi34-309.txt': 3,
#  'afi34-501.txt': 1,
#  'afi34-511.txt': 1,
#  'afi35-102.txt': 1,
#  'afi35-104.txt': 2,
#  'afi35-108.txt': 1,
#  'afi35-109.txt': 4,
#  'afi35-110.txt': 3,
#  'afi35-113_.txt': 1,
#  'afi35-114.txt': 2,
#  'afi36-1004.txt': 2,
#  'afi36-102.txt': 4,
#  'afi36-105.txt': 2,
#  'afi36-117.txt': 4,
#  'afi36-1301.txt': 2,
#  'afi36-1901.txt': 2,
#  'afi36-2002.txt': 4,
#  'afi36-2005.txt': 5,
#  'afi36-2009.txt': 1,
#  'afi36-202.txt': 1,
#  'afi36-205.txt': 1,
#  'afi36-2102v3.txt': 1,
#  'afi36-2109.txt': 3,
#  'afi36-2110.txt': 4,
#  'afi36-2113.txt': 2,
#  'afi36-2129.txt': 4,
#  'afi36-2131.txt': 1,
#  'afi36-2132v1.txt': 1,
#  'afi36-2132v2.txt': 2,
#  'afi36-2135.txt': 1,
#  'afi36-2201.txt': 1,
#  'afi36-2249.txt': 1,
#  'afi36-2254v1.txt': 2,
#  'afi36-2254v2.txt': 1,
#  'afi36-2305.txt': 5,
#  'afi36-2406.txt': 3,
#  'afi36-2501.txt': 1,
#  'afi36-2502.txt': 1,
#  'afi36-2602.txt': 2,
#  'afi36-2603.txt': 1,
#  'afi36-2606.txt': 3,
#  'afi36-2608.txt': 1,
#  'afi36-2616.txt': 6,
#  'afi36-2617.txt': 4,
#  'afi36-2618.txt': 1,
#  'afi36-2619.txt': 5,
#  'afi36-2623.txt': 2,
#  'afi36-2626.txt': 3,
#  'afi36-2629.txt': 1,
#  'afi36-2640_(certified_current)).txt': 1,
#  'afi36-2644.txt': 4,
#  'afi36-2645.txt': 3,
#  'afi36-2646.txt': 2,
#  'afi36-2649.txt': 4,
#  'afi36-2650.txt': 4,
#  'afi36-2654.txt': 7,
#  'afi36-2706.txt': 1,
#  'afi36-2803.txt': 1,
#  'afi36-2807.txt': 3,
#  'afi36-2811.txt': 1,
#  'afi36-2816.txt': 1,
#  'afi36-2817.txt': 5,
#  'afi36-2818.txt': 1,
#  'afi36-2820.txt': 3,
#  'afi36-2824.txt': 1,
#  'afi36-2831.txt': 5,
#  'afi36-2833.txt': 2,
#  'afi36-2835.txt': 2,
#  'afi36-2844.txt': 1,
#  'afi36-2848.txt': 1,
#  'afi36-2855.txt': 6,
#  'afi36-2863.txt': 2,
#  'afi36-2868.txt': 2,
#  'afi36-2870.txt': 3,
#  'afi36-2901.txt': 4,
#  'afi36-2905.txt': 2,
#  'afi36-2906.txt': 2,
#  'afi36-2907.txt': 1,
#  'afi36-2908.txt': 3,
#  'afi36-2909.txt': 2,
#  'afi36-2911.txt': 5,
#  'afi36-2921.txt': 1,
#  'afi36-2925.txt': 2,
#  'afi36-3002.txt': 3,
#  'afi36-3003.txt': 3,
#  'afi36-3004.txt': 4,
#  'afi36-3009.txt': 4,
#  'afi36-3014.txt': 2,
#  'afi36-3017.txt': 4,
#  'afi36-3024.txt': 1,
#  'afi36-3026v1_ip.txt': 5,
#  'afi36-3034.txt': 3,
#  'afi36-3035.txt': 5,
#  'afi36-3103.txt': 2,
#  'afi36-3106_.txt': 3,
#  'afi36-3107.txt': 5,
#  'afi36-3108.txt': 1,
#  'afi36-3111.txt': 4,
#  'afi36-3202.txt': 1,
#  'afi36-3203_.txt': 2,
#  'afi36-3204.txt': 3,
#  'afi36-3208.txt': 1,
#  'afi36-3503.txt': 1,
#  'afi36-3802.txt': 1,
#  'afi36-3803.txt': 5,
#  'afi36-4001.txt': 2,
#  'afi36-4002.txt': 3,
#  'afi36-4003.txt': 2,
#  'afi36-502.txt': 3,
#  'afi36-701.txt': 4,
#  'afi36-703.txt': 3,
#  'afi36-706.txt': 3,
#  'afi36-801.txt': 1,
#  'afi36-802.txt': 1,
#  'afi36-807.txt': 5,
#  'afi36-809.txt': 2,
#  'afi36-8101.txt': 2,
#  'afi36-815.txt': 1,
#  'afi36-816.txt': 5,
#  'afi36-817.txt': 3,
#  'afi38-101.txt': 3,
#  'afi38-201.txt': 1,
#  'afi38-204.txt': 1,
#  'afi38-206.txt': 1,
#  'afi38-401.txt': 3,
#  'afi38-402.txt': 4,
#  'afi38-601.txt': 5,
#  'afi40-101.txt': 5,
#  'afi40-102.txt': 4,
#  'afi40-104.txt': 5,
#  'afi40-201.txt': 4,
#  'afi40-301.txt': 5,
#  'afi40-701.txt': 4,
#  'afi41-102.txt': 1,
#  'afi41-103.txt': 2,
#  'afi41-104.txt': 5,
#  'afi41-105.txt': 5,
#  'afi41-106.txt': 5,
#  'afi41-108.txt': 3,
#  'afi41-109.txt': 3,
#  'afi41-110.txt': 5,
#  'afi41-117.txt': 6,
#  'afi41-126.txt': 1,
#  'afi41-200.txt': 6,
#  'afi41-201.txt': 2,
#  'afi41-209.txt': 1,
#  'afi41-210.txt': 1,
#  'afi44-102.txt': 4,
#  'afi44-103.txt': 1,
#  'afi44-104.txt': 6,
#  'afi44-105.txt': 2,
#  'afi44-108.txt': 5,
#  'afi44-110.txt': 2,
#  'afi44-119.txt': 1,
#  'afi44-121.txt': 6,
#  'afi44-153.txt': 3,
#  'afi44-162.txt': 3,
#  'afi44-170.txt': 4,
#  'afi44-171.txt': 5,
#  'afi44-172.txt': 4,
#  'afi44-173.txt': 1,
#  'afi44-176.txt': 6,
#  'afi44-177.txt': 4,
#  'afi44-178.txt': 5,
#  'afi46-101.txt': 6,
#  'afi47-101.txt': 3,
#  'afi48-101.txt': 2,
#  'afi48-102.txt': 6,
#  'afi48-105.txt': 5,
#  'afi48-109.txt': 1,
#  'afi48-112.txt': 4,
#  'afi48-114.txt': 3,
#  'afi48-116.txt': 4,
#  'afi48-117.txt': 5,
#  'afi48-122.txt': 6,
#  'afi48-123.txt': 1,
#  'afi48-127.txt': 3,
#  'afi48-137.txt': 6,
#  'afi48-139.txt': 6,
#  'afi48-144.txt': 2,
#  'afi48-145.txt': 4,
#  'afi48-148.txt': 3,
#  'afi48-149.txt': 7,
#  'afi48-151.txt': 3,
#  'afi48-158.txt': 2,
#  'afi48-307v1.txt': 5,
#  'afi48-307v2.txt': 5,
#  'afi48-307v3.txt': 6,
#  'afi51-1001.txt': 4,
#  'afi51-101.txt': 3,
#  'afi51-103.txt': 1,
#  'afi51-104.txt': 6,
#  'afi51-105.txt': 5,
#  'afi51-108.txt': 6,
#  'afi51-109.txt': 4,
#  'afi51-110.txt': 5,
#  'afi51-1101.txt': 1,
#  'afi51-1102.txt': 5,
#  'afi51-1301.txt': 5,
#  'afi51-1302.txt': 1,
#  'afi51-201.txt': 1,
#  'afi51-202.txt': 5,
#  'afi51-302.txt': 1,
#  'afi51-401.txt': 5,
#  'afi51-501.txt': 5,
#  'afi51-502.txt': 6,
#  'afi51-503.txt': 3,
#  'afi51-504.txt': 1,
#  'afi51-602.txt': 2,
#  'afi51-604.txt': 2,
#  'afi51-702.txt': 7,
#  'afi51-703.txt': 2,
#  'afi51-704.txt': 3,
#  'afi51-705.txt': 3,
#  'afi51-801.txt': 1,
#  'afi51-802.txt': 6,
#  'afi51-901.txt': 2,
#  'afi51-903.txt': 1,
#  'afi51-904.txt': 5,
#  'afi51-905.txt': 5,
#  'afi52-101.txt': 3,
#  'afi52-102v1.txt': 1,
#  'afi52-102v2.txt': 3,
#  'afi52-104.txt': 7,
#  'afi52-105.txt': 2,
#  'afi52-106.txt': 5,
#  'afi60-101.txt': 4,
#  'afi60-106.txt': 4,
#  'afi61-101.txt': 2,
#  'afi61-201.txt': 3,
#  'afi63-125.txt': 2,
#  'afi63-137.txt': 1,
#  'afi63-140.txt': 1,
#  'afi63-141.txt': 3,
#  'afi63-145.txt': 2,
#  'afi64-102.txt': 3,
#  'afi64-103.txt': 1,
#  'afi64-105.txt': 5,
#  'afi64-106.txt': 5,
#  'afi64-117.txt': 1,
#  'afi64-201.txt': 1,
#  'afi65-106.txt': 1,
#  'afi65-118.txt': 2,
#  'afi65-201.txt': 2,
#  'afi65-401.txt': 2,
#  'afi65-501.txt': 2,
#  'afi65-502.txt': 1,
#  'afi65-508.txt': 1,
#  'afi65-601v1.txt': 1,
#  'afi65-601v2.txt': 1,
#  'afi65-601v3.txt': 1,
#  'afi65-603.txt': 1,
#  'afi65-607.txt': 1,
#  'afi65-608.txt': 2,
#  'afi71-101v1.txt': 5,
#  'afi71-101v2.txt': 4,
#  'afi71-101v3.txt': 4,
#  'afi71-101v4.txt': 5,
#  'afi84-101.txt': 2,
#  'afi84-102.txt': 1,
#  'afi84-103.txt': 2,
#  'afi90-1601.txt': 3,
#  'afi90-1603.txt': 6,
#  'afi90-1701.txt': 1,
#  'afi90-2001.txt': 2,
#  'afi90-2002.txt': 3,
#  'afi90-201.txt': 6,
#  'afi90-301.txt': 2,
#  'afi90-501.txt': 6,
#  'afi90-505.txt': 6,
#  'afi90-506.txt': 2,
#  'afi90-507.txt': 5,
#  'afi90-508.txt': 4,
#  'afi90-6001.txt': 5,
#  'afi90-801.txt': 2,
#  'afi90-821.txt': 4,
#  'afi91-101.txt': 2,
#  'afi91-102.txt': 3,
#  'afi91-103.txt': 3,
#  'afi91-104.txt': 3,
#  'afi91-105.txt': 5,
#  'afi91-106.txt': 4,
#  'afi91-107.txt': 3,
#  'afi91-108.txt': 2,
#  'afi91-110.txt': 4,
#  'afi91-111.txt': 3,
#  'afi91-112.txt': 5,
#  'afi91-114.txt': 3,
#  'afi91-115.txt': 3,
#  'afi91-116.txt': 3,
#  'afi91-117.txt': 5,
#  'afi91-121.txt': 3,
#  'afi91-202.txt': 4,
#  'afi91-203.txt': 3,
#  'afi91-204.txt': 2,
#  'afi91-205.txt': 1,
#  'afi91-207.txt': 1,
#  'afi91-208.txt': 2,
#  'afi91-217.txt': 4,
#  'afi91-225.txt': 1,
#  'afi99-103.txt': 1,
#  'afi99-106.txt': 1,
#  'afi99-107.txt': 3,
#  'afi99-109.txt': 3,
#  'afi99-120.txt': 4,
#  'afi99-151.txt': 3,
#  'afi_14-2c-5&17.txt': 20,
#  'afi_14-2ec-130hv2.txt': 52,
#  'afi_14-2tnkr.txt': 20,
#  'afi_17-2acdv1.txt': 13,
#  'afi_36-2604.txt': 1,
#  'afi_36-2829.txt': 2,
#  'afi_36-2871.txt': 1,
#  'afi_36-3020.txt': 1,
#  'afi_36-3701.txt': 1,
#  'afi_51-107.txt': 3}

# %%
def get_docs_from_sent(sent):
    this_hash = sent_to_hash[sent]
    return list(baskets[this_hash])

# %%
def search_for_doc(doc_name):
    sents = {}
    for k,v in trimmed_baskets.items():
        if doc_name in v:
            this_sent = hash_to_sent[k]
            #sents.append(this_sent)
            the_docs = get_docs_from_sent(this_sent)
            sents[this_sent] = (the_docs,len(the_docs))
            #shared_docs = 
            #print("{} in {}".format(k, doc_name))
    return sents

# %%
ec130results = search_for_doc('afi11-2ec-130hv3.txt')

# %%
import pickle
with open('ec130results.pickle','wb') as myfile:
    pickle.dump(ec130results,myfile)

# %%
# trim baskets

def trim_baskets(baskets, min_size=3):
    return {k:v for k,v in tqdm(baskets.items()) if len(v) > min_size}

# %%
trimmed_baskets = trim_baskets(baskets, min_size=6)
# Out:
# 100%|██████████| 508484/508484 [00:00<00:00, 1421388.42it/s]

# %%
len(list(baskets.items()))
# Out:
# 508484

# %%
hash_to_sent[(-5011513889702821403, -7321025647363460706)]
# Out:
# 'To the extent its directions are inconsistent with other Air Force publications, the information herein prevails, in accordance with AFI 33-360, Publications and Forms Management.'

# %%
# For a given document,
# Output a list of sentences it shares with others, and for each sentence, what those references are
# For a given reference, determine its cosine similarity.

# %%
get_occurrence_count_of_sentence('To the extent its directions are inconsistent with other Air Force publications, the information herein prevails, in accordance with AFI 33-360, Publications and Forms Management.')
# Out:
# (35,
#  ['afi10-201.txt',
#   'afi32-7062.txt',
#   'afi24-301.txt',
#   'afi11-202v3.txt',
#   'afi90-6001.txt',
#   'afi10-1703v1.txt',
#   'afi32-1032.txt',
#   'afi10-244.txt',
#   'afi10-1703v2.txt',
#   'afi10-1703v3.txt',
#   'afi13-1stan-evalv2.txt',
#   'afi36-2201.txt',
#   'afi91-204.txt',
#   'afi51-110.txt',
#   'afi10-2519.txt',
#   'afi36-3003.txt',
#   'afi51-703.txt',
#   'afi36-2254v1.txt',
#   'afi90-505.txt',
#   'afi33-364.txt',
#   'afi32-1023.txt',
#   'afi36-202.txt',
#   'afi1-404.txt',
#   'afi33-360.txt',
#   'afi31-105.txt',
#   'afi64-201.txt',
#   'afi91-202.txt',
#   'afi36-2249.txt',
#   'afi17-140.txt',
#   'afi36-807.txt',
#   'afi11-401.txt',
#   'afi14-104.txt',
#   'afi32-7001.txt',
#   'afi10-2501.txt',
#   'afi10-403.txt'])

# %%
def get_occurrence_count_of_sentence(sentence, is_hash=False):
    if is_hash:
        this_hash = sentence
    else:
        this_hash = sent_to_hash[sentence]
    occurrences = list(trimmed_baskets[this_hash])
    return (len(occurrences),occurrences)

# %%
hash_to_sent[popular_hash]
# Out:
# 'U. Did not properly identify aircraft category or exceeded the lateral limits of circling airspace.'

# %%
len(list(trimmed_baskets.items()))
# Out:
# 1492

# %% [markdown]
# Now we build a graph from the baskets, each combination of documents in each bucket is related to each other.. and the edge weight between documents is based on how many buckets they share. We also determine series here and enrich the node with that, so we can compare how links within or across series work.

# %%
import networkx as nx
from itertools import combinations
# Build a weighted graph from the baskets

def traverse_baskets(baskets):   
    graph = nx.Graph()
    for k,v in baskets.items():
        combs = combinations(v, 2)
        for comb in combs:
            # ensure nodes exist
            if comb[0] not in graph:
                graph.add_node(comb[0], series=comb[0].split('-')[0][-2:]) # split on '-' and take the last 2 chars from first part of split result
            if comb[1] not in graph:
                graph.add_node(comb[1], series=comb[1].split('-')[0][-2:]) # e.g. afi_12-21 -> 12; afi12-22 -> 12
            
            # if already exists, increment
            if comb[0] in graph[comb[1]]:
                curr_wt = graph.edges[comb[0], comb[1]]['weight']
                series_same = comb[0].split('-')[0][-2:] == comb[1].split('-')[0][-2:]
                graph.add_edge(comb[0],comb[1], weight=curr_wt+1, label="{}-{}".format(comb[0],comb[1]),sameseries="{}".format(series_same))
            # create new link
            else:
                series_same = comb[0].split('-')[0][-2:] == comb[1].split('-')[0][-2:]
                graph.add_edge(comb[0],comb[1], weight=1, label="{}-{}".format(comb[0],comb[1]), sameseries="{}".format(series_same))
    return graph

# %%
graph = traverse_baskets(trimmed_baskets)

# %%
len(graph.edges())

# %% [markdown]
# More noise reduction.. prune nodes/edges that only share 1 bucket.

# %%
# Trim graphs with only 1 link
def prune_graph(graph):
    removal_candidates = []
    for edge in graph.edges():
        if graph.edges()[edge]['weight'] < 2:
            removal_candidates.append((edge[0],edge[1]))
    # remove low weight edges
    graph.remove_edges_from(removal_candidates)
    # remove isolate nodes
    graph.remove_nodes_from(list(nx.isolates(graph)))
    return graph

# %%
sample_str = """General. The AEF is the Air Force‟s force generation construct used to manage the battle
rhythm of expeditionary forces in order to meet global CCDR requirements while maintaining
the highest possible level of overall readiness. Through the AEF, the Air Force establishes a
predictable, standardized battle rhythm ensuring rotational forces are properly organized, trained,
equipped, and ready to sustain capabilities while rapidly responding to emerging crises. Through
the AEF, the Air Force supports defense strategy requirements using a combination of both
permanently assigned and rotational (allocated) forces.
1.1.1. How to use this AFI. This AFI governs Unit Type Code (UTC) readiness reporting.
This instruction should be followed in the context of AFI 10-401 Air Force Operations
Planning and Execution, which contains planning considerations for these UTCs and a full
description of AEF concepts. In cases where this AFI and AFI 10-401 contradict, AFI 10-401
will take precedence. Chapter 1 contains the basic description of the AEF and AEF UTC
Reporting Tool (ART). Chapter 2 outlines roles and responsibilities in UTC reporting.
Chapter 3 describes assessment and reporting policies.
1.2. Reporting AEF Readiness - General. To view the health of USAF forces postured in the
UTC Availability (UTA), Air Force senior leadership determined the need to collect UTC
readiness data from ART reportable units in sufficient detail to support the following goals:
1.2.1. Provide HQ USAF, AF Component Commanders, AF components to Joint Force
Providers (JFPs), MAJCOM's, and the Directorate of Air and Space Expeditionary Forces
Operations (AFPC/DPW) readiness information to employ, manage, and sustain AEF
operations.
1.2.2. Provide units a mechanism to report a UTC‟s ability or inability to fulfill its Mission
Capability Statement (MISCAP) across the full range of military operations (ROMO), to
include contingency and rotational operations, and highlight associated deficiencies within
the UTC.
1.2.3. Provide information to aid resource allocation and tasking decisions during steady
state and crisis actions.
1.3. System Description. The AEF UTC Reporting Tool (ART) allows units the ability to
report UTC level readiness data. It provides one central location to archive reported data. It
allows immediate updates and ready access to an aggregate UTC status for all levels of
command with sufficient depth of information to make informed decisions on the employment of
forces for AEF operations. It further provides a means for identifying and analyzing actionable
indicators of change.
1.3.1. ART is a web-based, non-intrusive, html-environment tool with associated databases
to support collection, collation, and report generation of unit and aggregate UTC readiness
data. It resides on the SIPRNET (https://aef.afpc.randolph.af.smil.mil) for secure access.
Units that have standard UTCs postured in UTC Availability."""

# %%
# Determine readability of a sentence
# Sentences with longer length and higher average syllable size are less readable
# for each sentence in the corpus..
# build a dict of sentences, where we characterize number of words, average length of words, average syllables/word
from textstat import syllable_count
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-bbdf942da183> in <module>()
#       3 # for each sentence in the corpus..
#       4 # build a dict of sentences, where we characterize number of words, average length of words, average syllables/word
# ----> 5 from textstat import syllable_count
#
# ImportError: cannot import name 'syllable_count'

# %%
def analyze_doc(doc_txt):
    MIN_SENT_LEN = 12
    for sent in nlp(doc_txt).sents:
        if len(sent) > MIN_SENT_LEN:
            print("syllables {}".format(syllable_count(sent.text)))
            print(sent)

# %%
analyze_doc(sample_str)
